# %%
from sympy import *

# %%
matplotlib notebook

# %%
import numpy as np #NOTE: Since we already imported from sympy, we will use a  import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
X1, X2 = np.meshgrid(np.arange(-3, 3.01, .25), np.arange(-3, 3.01, .25)) # adju X1p = 1*X1+1*X2
X1p = 2*X1-X2
X2p = 3*X1-2*X2
#Normalize the arrows by dividing by their magnitude (focus on direction) U=1/(X1p**2+X2p**2)**(0.5)*X1p
U=1/(X1p**2+X2p**2)**(0.5)*X1p
V=1/(X1p**2+X2p**2)**(0.5)*X2p
plt.figure()
plt.title('Phase Plane for [[2,-1],[3,-2]]')
Q = plt.quiver(X1, X2, U, V) # draws the normalized arrows at (X,Y) with slope dYdX
# Out:
# /var/folders/41/0247d0vn145501g4fkvcb7d80000gn/T/ipykernel_99193/2387279584.py:7: RuntimeWarning: divide by zero encountered in divide
#   U=1/(X1p**2+X2p**2)**(0.5)*X1p
# /var/folders/41/0247d0vn145501g4fkvcb7d80000gn/T/ipykernel_99193/2387279584.py:7: RuntimeWarning: invalid value encountered in multiply
#   U=1/(X1p**2+X2p**2)**(0.5)*X1p
# /var/folders/41/0247d0vn145501g4fkvcb7d80000gn/T/ipykernel_99193/2387279584.py:8: RuntimeWarning: divide by zero encountered in divide
#   V=1/(X1p**2+X2p**2)**(0.5)*X2p
# /var/folders/41/0247d0vn145501g4fkvcb7d80000gn/T/ipykernel_99193/2387279584.py:8: RuntimeWarning: invalid value encountered in multiply
#   V=1/(X1p**2+X2p**2)**(0.5)*X2p
# <img src="data:image/png;base64,..." width="640">
